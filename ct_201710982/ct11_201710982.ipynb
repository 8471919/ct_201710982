# %% [markdown]
# <H1>안녕 이건 큰 글씨야!! </H1>
# <H2>안녕 조금 작은 큰 글씨야!! </H2>

# %% [markdown]
# # 큰 글씨
# ## 작은 글씨
# ### 더 작은 글씨

# %% [markdown]
# * 도시
#     * 서울
#     * 시드니
#     * 뉴욕
#        * 1번가
#         * 33번가

# %%
print "hello"
print "1+2=", 1+2
# Out:
# hello
# 1+2= 3

# %%
from PIL import Image

# %%
m = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.jpg")

# %%
m.show()

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(m)

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.png")

# %%
mygif = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.jpg")

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(mygif)

# %% [markdown]
# * jpg파일을 gif파일로 변환하기
#     * 파일확장자를 gif로 적어준다.

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.gif")

# %%
myjpg = Image.open("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.jpg")

# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
imshow(myjpg)

# %%
m.save("C:\\Users\\400T6B\\Downloads\\italy-1587287_1920.jpg")

# %% [markdown]
# * Operator overloading
#    * '+'가 숫자를 만나면

# %%
print 2*3
# Out:
# 6

# %%
print "hello " *3
# Out:
# hello hello hello

# %% [markdown]
# * startswith() 기능 배우기

# %%
s="Hello World"
s.startswith('H')
# Out:
# True

# %%
type(s)
# Out:
# str

# %%
s1="123"
s2="111"
type(s1)
# Out:
# str

# %%
int(s1)+int(s2)
# Out:
# 234

# %%
print s[0] =='H'
# Out:
# True

# %%
msg='She says "Good morning!"'
print msg
# Out:
# She says "Good morning!"

# %%
s.endswith("d")
# Out:
# True

# %%
len(s)
# Out:
# 11

# %%
for ch in s:
    print ch,
# Out:
# H e l l o   W o r l d

# %%
for i in range(0,11):
    print s[i],
# Out:
# H e l l o   W o r l d

# %%
for i in range(0,len(s)):
    print s[i],
# Out:
# H e l l o   W o r l d

# %%
s.index("Wor")
# Out:
# 6

# %%
s.strip('rld')
# Out:
# 'Hello Wo'

# %%
s1="Hello\n\tworld\n"
print s1
# Out:
# Hello
# 	world

# %%
print s1.strip()
# Out:
# Hello
# 	world

# %%
print s[-1]
# Out:
# d

# %%
print s[0:5]
# Out:
# Hello

# %%
print s[:]
# Out:
# Hello World

# %%
#과제시발 #
